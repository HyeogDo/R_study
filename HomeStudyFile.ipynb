# %%
rDat <- read.csv("C:/Users/khdo/Downloads/서울시 강동구 보건소 홈페이지 새소식 정보.csv", stringsAsFactors = F)

# %%
head(rDat)
# Out:
#   게시물.ID 게시물.순번
# 1 1140      171935
# 2 1140      171319
# 3 1140      171183
# 4 1140      170797
# 5 1140      170310
# 6 1140      169660
#   게시물.제목
# 1 (음식점 유흥시설) 수도권 사회적 거리두기 조정에 따른 방역조치 고시
# 2 유흥시설 종사자 코로나19 진단검사 안내
# 3 (음식점 유흥시설 등) 수도권 사회적 거리두기 조정에 따른 방역조치 안내
# 4 (음식점) 코로나19 확산 방지를 위한 외국인 노동자 진단검사 행정명령 알림
# 5 (음식점 유흥시설 등) 사회적 거리두기 조정에 따른 방역조치 안내
# 6 (음식점 유흥시설 등) 사회적 거리두기 연장에 따른 방역조치 안내
#   게시글.내용
# 1 <p><img alt='1' src='/upload/ckeditor/Image/1_48.jpg' /><img alt='2' src='/upload/ckeditor/Image/2_34.jpg' /><img alt='3' src='/upload/ckeditor/Image/3_28.jpg' /><img alt='4' src='/upload/ckeditor/Image/4_20.jpg' /><img alt='5' src='/upload/ckeditor/Image/5_14.jpg' /><img alt='6' src='/upload/ckeditor/Image/6_8.jpg' /></p>
# 2 <p><img alt='1' src='/upload/ckeditor/Image/11_10.jpg' /></p>
# ...

# %%
tail(rDat)
# Out:
#    게시물.ID 게시물.순번 게시물.제목
# 61 1140      39394       인플루엔자 유행주의보 안내
# 62 1140      39374       청소년 산모 의료비 지원 안내
# 63 1140      39347       ‘12. 1월 야간 식품접객업소 위생점검 사전예고
# 64 1140      39257       2012. 1월중 식품접객업소 위생점검 사전 예고
# 65 1140      39256       2012. 설맞이 다중이용 음식점 특별점검 실시
# 66 1140      39191       연말연시 야간 주류전문업소 위생점검
# ...

# %%
str(rDat)
# Out:
# 'data.frame':	66 obs. of  7 variables:
#  $ 게시물.ID  : int  1140 1140 1140 1140 1140 1140 1140 1140 1140 1140 ...
#  $ 게시물.순번: int  171935 171319 171183 170797 170310 169660 169122 168706 168533 168447 ...
#  $ 게시물.제목: chr  "(음식점 유흥시설) 수도권 사회적 거리두기 조정에 따른 방역조치 고시" "유흥시설 종사자 코로나19 진단검사 안내" "(음식점 유흥시설 등) 수도권 사회적 거리두기 조정에 따른 방역조치 안내" "(음식점) 코로나19 확산 방지를 위한 외국인 노동자 진단검사 행정명령 알림" ...
#  $ 게시글.내용: chr  "<p><img alt='1' src='/upload/ckeditor/Image/1_48.jpg' /><img alt='2' src='/upload/ckeditor/Image/2_34.jpg' /><i"| __truncated__ "<p><img alt='1' src='/upload/ckeditor/Image/11_10.jpg' /></p> " "<p><img alt='1' src='/upload/ckeditor/Image/1_46.jpg' /><img alt='2' src='/upload/ckeditor/Image/2_32.jpg' /><i"| __truncated__ "<p><img alt='11' src='/upload/ckeditor/Image/11_8.jpg' /><img alt='22' src='/upload/ckeditor/Image/22_3.jpg' /></p> " ...
#  $ 조회수     : int  1520 58 49 72 23 1610 1784 34 30 68 ...
# ...

# %%
summary(rDat)
# Out:
#    게시물.ID     게시물.순번     게시물.제목        게시글.내용
#  Min.   :1140   Min.   : 39191   Length:66          Length:66
#  1st Qu.:1140   1st Qu.: 40220   Class :character   Class :character
#  Median :1140   Median : 42401   Mode  :character   Mode  :character
#  Mean   :1140   Mean   : 80758
#  3rd Qu.:1140   3rd Qu.:165934
#  Max.   :1140   Max.   :171935
#      조회수         등록일시           수정일시
#  Min.   :   5.0   Length:66          Length:66
#  1st Qu.: 115.5   Class :character   Class :character
#  Median :2256.5   Mode  :character   Mode  :character
#  Mean   :1796.9
#  3rd Qu.:2592.0
#  Max.   :3710.0

# %%
regDate <- as.Date(rDat[,"등록일시"])
class(regDate)
print(regDate)
# Out:
# [1] "Date"
#  [1] "2021-05-03" "2021-04-07" "2021-04-02" "2021-03-18" "2021-03-02"
#  [6] "2021-02-03" "2021-01-18" "2021-01-04" "2020-12-28" "2020-12-23"
# [11] "2020-12-18" "2020-12-07" "2020-12-01" "2020-11-30" "2020-11-09"
# [16] "2020-10-28" "2020-10-12" "2020-10-12" "2020-10-12" "2020-08-28"
# [21] "2015-07-06" "2015-06-17" "2012-12-20" "2012-11-23" "2012-10-24"
# [26] "2012-10-24" "2012-10-11" "2012-09-25" "2012-09-25" "2012-09-19"
# [31] "2012-08-31" "2012-07-25" "2012-07-09" "2012-06-26" "2012-06-22"
# [36] "2012-06-19" "2012-05-23" "2012-05-19" "2012-05-08" "2012-05-07"
# [41] "2012-04-24" "2012-04-23" "2012-04-18" "2012-04-13" "2012-04-09"
# [46] "2012-04-03" "2012-03-28" "2012-03-19" "2012-03-13" "2012-03-12"
# [51] "2012-03-07" "2012-03-05" "2012-02-29" "2012-02-24" "2012-02-08"
# [56] "2012-02-08" "2012-02-03" "2012-01-26" "2012-01-26" "2012-01-26"
# [61] "2012-01-19" "2012-01-18" "2012-01-16" "2012-01-10" "2012-01-10"
# [66] "2012-01-03"

# %%
readDat <- read.table("C:/Users/khdo/Downloads/report.txt", sep = "\t",header = T, fileEncoding = "utf-8", stringsAsFactors = F)
resultDat <- readDat[grep(paste(unique(readDat[,2])[1:5], collapse = "|"), readDat[,2]),]
resultDat
# Out:
#    기간 대분류 분류             전혀.느끼지.않았다 느끼지.않은.편이다 보통이다
# 1  2021 서울시 서울시           2.0                20.5               36.1
# 2  2021 성별   남자             2.0                19.1               37.6
# 3  2021 성별   여자             2.0                21.7               34.7
# 4  2021 연령별 10대             2.6                14.4               38.4
# 5  2021 연령별 20대             2.0                19.7               33.2
# 6  2021 연령별 30대             1.7                14.1               36.1
# 7  2021 연령별 40대             1.6                13.7               38.3
# 8  2021 연령별 50대             1.8                20.3               37.1
# 9  2021 연령별 60세 이상        2.7                30.9               35.4
# 10 2021 학력별 중졸 이하        3.2                34.2               33.4
# 11 2021 학력별 고졸 이하        2.1                22.9               36.3
# 12 2021 학력별 대졸 이하        1.8                17.5               36.7
# 13 2021 학력별 대학원 이상      1.9                10.6               35.0
# ...

# %%
subset(readDat, readDat[,2]== )
